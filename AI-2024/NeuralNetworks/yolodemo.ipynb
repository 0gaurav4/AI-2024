# %%
import ultralytics

# %%
model = ultralytics.YOLO('yolov8x')
# Out:
# ...
# 100%|██████████| 131M/131M [00:14<00:00, 9.66MB/s]

# %%
import cv2
import matplotlib.pyplot as plt

# %%
path = r"C:\Users\gaura\Desktop\Vool2024\AI-2024-main\AI-2024\comvision\truck.jpg"
img = cv2.imread(path)
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img)
plt.axis("off")
plt.show()

# %%
result = model(path, project='yolo_demo', save=True)
# Out:
# image 1/1 C:\Users\gaura\Desktop\Vool2024\AI-2024-main\AI-2024\comvision\truck.jpg: 384x640 1 truck, 14775.1ms
# Speed: 78.8ms preprocess, 14775.1ms inference, 67.2ms postprocess per image at shape (1, 3, 384, 640)
# Results saved to yolo_demo\predict

# %%
model(r"C:\Users\gaura\Desktop\Vool2024\projectV\1.mp4", project='yolo_demo', save=True)
# Out:
# WARNING  inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/132) C:\Users\gaura\Desktop\Vool2024\projectV\1.mp4: 384x640 (no detections), 13514.6ms
# video 1/1 (frame 2/132) C:\Users\gaura\Desktop\Vool2024\projectV\1.mp4: 384x640 (no detections), 11468.3ms
# video 1/1 (frame 3/132) C:\Users\gaura\Desktop\Vool2024\projectV\1.mp4: 384x640 1 dog, 12296.3ms
# video 1/1 (frame 4/132) C:\Users\gaura\Desktop\Vool2024\projectV\1.mp4: 384x640 1 cat, 11495.0ms
# ...
