# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
titanic_data = pd.read_csv('../data/titanic.csv')
titanic_data.head(2)
# Out:
#    PassengerId   Survived     Pclass  \
# 1            0          3    "Braund
# 2            1          1   "Cumings
#
#    Name                                                                                  \
# 1   Mr. Owen Harris"                             ...
# 2   Mrs. John Bradley (Florence Briggs Thayer)"  ...
#
#     Sex      Age    SibSp   Parch   Ticket               Fare      \
# 1   male     22         1       0   A/5 21171              7.2500
# 2   female   38         1       0   PC 17599              71.2833
#
#     Cabin            Embarked
# 1                           S
# 2   C85                     C

# %%
#to rename column names
titanic_data.rename(columns={' Age ':'Age'}, inplace=True)
titanic_data.rename(columns={' SibSp':'SibSp'}, inplace=True)
titanic_data.rename(columns={' Parch':'Parch'}, inplace=True)
titanic_data.rename(columns={' Embarked':'Embarked'}, inplace=True)
titanic_data.rename(columns={' Pclass':'Pclass'}, inplace=True)
titanic_data.rename(columns={' Survived':'Survived'}, inplace=True)
titanic_data.rename(columns={' Fare    ':'Fare'}, inplace=True)
titanic_data.rename(columns={' Sex   ':'Sex'}, inplace=True)
titanic_data.rename(columns={' Ticket            ':'Ticket'}, inplace=True)
titanic_data.rename(columns={' Cabin          ':'Cabin'}, inplace=True)
titanic_data.rename(columns={' Name                                                                                ':'Name'}, inplace=True)

# %% [markdown]
# # Bar Plot:
# Show the count of passengers who survived and those who didn't.

# %%
# Count survived vs not survived
survived_count = titanic_data['Survived'].value_counts()

# Plotting
plt.bar(survived_count.index.astype(str), survived_count.values)
plt.xlabel('Survival Status')
plt.ylabel('Count')
plt.title('Survival Count')
plt.show()

# %% [markdown]
# # Histogram:
# Show the distribution of passenger ages.

# %%
# Drop missing values in 'age' column
age_data = titanic_data['Age'].dropna()

# Plotting
plt.hist(age_data, bins=20, edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Passenger Age Distribution')
plt.show()

# %% [markdown]
# # Pie Chart:
# Show the distribution of passengers by class.

# %%
# Count passengers by class
class_counts = titanic_data['Pclass'].value_counts()

print(class_counts.index)

# Plotting
plt.pie(class_counts, labels=class_counts.index, autopct='%1.1f%%', startangle=180)
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Passenger Class Distribution')
plt.show()
# Out:
# Index([' "Andersson', ' "Sage', ' "Panula', ' "Skoog', ' "Carter', ' "Goodwin',
#        ' "Johnson', ' "Rice', ' "Lefebre', ' "Asplund',
#        ...
#        ' "Hendekovic', ' "Lahtinen', ' "Francatelli', ' "Fleming',
#        ' "Saalfeld', ' "Hanna', ' "Lewy', ' "Mineff', ' "Haas', ' "Dooley'],
#       dtype='object', name='Pclass', length=667)

# %% [markdown]
# # Scatter Plot:
# Show the relationship between fare and age of passengers.

# %%
# Plotting
plt.scatter(titanic_data['Age'], titanic_data['Fare'], alpha=0.3)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare vs Age')
plt.show()

# %%
# plot size
plt.figure(figsize = (12,6))

plt.scatter(titanic_data['Age'], titanic_data['Fare'], alpha=0.5)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare vs Age')
plt.show()

# %% [markdown]
# # Bar Plot with Grouping:
# Show the count of passengers who survived or not survived based on gender.

# %%
titanic_data.groupby(['Sex', 'Survived']).size().unstack()
# Out:
# Survived    1    2    3
# Sex
# female     94   76  144
# male      122  108  347

# %%
# Grouping data by 'sex' and 'survived' columns
survived_by_sex = titanic_data.groupby(['Sex', 'Survived']).size().unstack()

# Plotting
survived_by_sex.plot(kind='bar', stacked=True)
plt.xlabel('Sex')
plt.ylabel('Count')
plt.title('Survival Count by Gender')
plt.legend(['Not Survived', 'Survived'], loc='upper left')
plt.show()

# %% [markdown]
# # Fare Distribution by Class:
# Compare the fare distribution across different passenger classes.

# %%
# Plot
plt.hist(titanic_data[titanic_data['Pclass'] == 1]['Fare'], bins=30, alpha=0.5, label='Class 1', color='green')
plt.hist(titanic_data[titanic_data['Pclass'] == 2]['Fare'], bins=30, alpha=0.5, label='Class 2', color='blue')
plt.hist(titanic_data[titanic_data['Pclass'] == 3]['Fare'], bins=30, alpha=0.5, label='Class 3', color='red')
plt.title('Fare Distribution by Class')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.legend()
plt.show()

# %%
# Grouping data by 'pclass' and 'survived', and then calculating survival rate
survival_rate_by_class = titanic_data.groupby('Pclass')['Survived'].mean()

# Plotting
survival_rate_by_class.plot(kind='bar', color='skyblue')
plt.title('Survival Rate by Passenger Class')
plt.xlabel('Passenger Class')
plt.ylabel('Survival Rate')
plt.xticks(rotation=-45)
plt.show()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
iris = pd.read_csv('../data/iris.csv')
iris.sample(10)  #random selection
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 70    71            5.9           3.2            4.8           1.8
# 3      4            4.6           3.1            1.5           0.2
# 74    75            6.4           2.9            4.3           1.3
# 81    82            5.5           2.4            3.7           1.0
# 136  137            6.3           3.4            5.6           2.4
# 67    68            5.8           2.7            4.1           1.0
# 69    70            5.6           2.5            3.9           1.1
# 86    87            6.7           3.1            4.7           1.5
# 101  102            5.8           2.7            5.1           1.9
# 114  115            5.8           2.8            5.1           2.4
#
#              Species
# 70   Iris-versicolor
# 3        Iris-setosa
# 74   Iris-versicolor
# 81   Iris-versicolor
# 136   Iris-virginica
# 67   Iris-versicolor
# 69   Iris-versicolor
# 86   Iris-versicolor
# 101   Iris-virginica
# ...

# %%
iris.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
iris.sample(10)
# Out:
# C:\Users\gaura\AppData\Local\Temp\ipykernel_20648\3531771219.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa':0,'Iris-versicolor':1,'Iris-virginica':2})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 123  124            6.3           2.7            4.9           1.8        2
# 75    76            6.6           3.0            4.4           1.4        1
# 80    81            5.5           2.4            3.8           1.1        1
# 52    53            6.9           3.1            4.9           1.5        1
# 45    46            4.8           3.0            1.4           0.3        0
# 98    99            5.1           2.5            3.0           1.1        1
# ...

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'])
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],alpha=0.7)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %%
plt.scatter(iris['SepalLengthCm'],iris['PetalLengthCm'],c=iris['Species'],cmap='jet',alpha=0.7)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.colorbar()

# %%
# List all available colormaps
plt.colormaps()
# Out:
# ['magma',
#  'inferno',
#  'plasma',
#  'viridis',
#  'cividis',
#  'twilight',
#  'twilight_shifted',
#  'turbo',
#  'Blues',
#  'BrBG',
#  'BuGn',
#  'BuPu',
#  'CMRmap',
#  'GnBu',
#  'Greens',
#  'Greys',
#  'OrRd',
#  'Oranges',
#  'PRGn',
#  'PiYG',
#  'PuBu',
#  'PuBuGn',
#  'PuOr',
#  'PuRd',
#  'Purples',
#  'RdBu',
#  'RdGy',
#  'RdPu',
#  'RdYlBu',
#  'RdYlGn',
#  'Reds',
#  'Spectral',
#  'Wistia',
#  'YlGn',
#  'YlGnBu',
#  'YlOrBr',
#  'YlOrRd',
#  'afmhot',
#  'autumn',
#  'binary',
#  'bone',
#  'brg',
#  'bwr',
#  'cool',
#  'coolwarm',
#  'copper',
#  'cubehelix',
#  'flag',
#  'gist_earth',
#  'gist_gray',
#  'gist_heat',
#  'gist_ncar',
#  'gist_rainbow',
#  'gist_stern',
#  'gist_yarg',
#  'gnuplot',
#  'gnuplot2',
#  'gray',
#  'hot',
#  'hsv',
#  'jet',
#  'nipy_spectral',
#  'ocean',
#  'pink',
#  'prism',
#  'rainbow',
#  'seismic',
#  'spring',
#  'summer',
#  'terrain',
#  'winter',
#  'Accent',
#  'Dark2',
#  'Paired',
#  'Pastel1',
#  'Pastel2',
# ...

# %% [raw]
# 'viridis': A perceptually uniform colormap that is often recommended for sequential data.
#
# 'plasma': Another perceptually uniform colormap that is similar to 'viridis' but with a different color scheme.
#
# 'inferno': A colormap with a dark-to-light scheme that is useful for representing heatmaps or density plots.
#
# 'magma': Similar to 'inferno', but with a different color scheme.
#
# 'cividis': A colormap designed to be perceptually uniform and accessible to viewers with color vision deficiencies.
#
# 'coolwarm': A diverging colormap that transitions smoothly from cool colors to warm colors, useful for visualizing data with a central point of interest.
#
# 'jet': A rainbow colormap that was commonly used in the past but is now discouraged due to its non-uniform perceptual changes and issues with colorblindness.
#
# 'rainbow': Similar to 'jet', but with improved perceptual uniformity.
#
# 'nipy_spectral': Another rainbow-like colormap that is more uniform than 'jet' but still not ideal for all situations.
#
# 'bone': A grayscale colormap with a slight blue tint, useful for representing images or continuous data.
#
# 'gray': A simple grayscale colormap ranging from black to white

# %% [markdown]
# # Annotations

# %%
batters = pd.read_csv('batter.csv')

# %%
batters.sample(10)
# Out:
#                batter  runs        avg  strike_rate
# 90             MM Ali   910  23.333333   139.570552
# 502          UA Birla     7   7.000000    46.666667
# 75           AR Patel  1135  19.237288   123.503808
# 347        HR Shokeen    43  21.500000    89.583333
# 403       KC Cariappa    24   8.000000   114.285714
# 186       Abdul Samad   228  13.411765   139.024390
# 477       T Henderson    11   5.500000    68.750000
# 50       Ishan Kishan  1870  29.218750   129.501385
# 51   DPMD Jayawardene  1808  28.250000   118.791064
# 47         MEK Hussey  1977  38.764706   119.963592

# %%
sample_df = batters.head(100).sample(25,random_state=5)
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

# %%
a=np.arange(1,6)
b=2*a
plt.scatter(a,b)
plt.text(1,2,"0th data")
plt.text(a[2],b[2],"2st data")
plt.text(a[-1],b[-1], 'last data')
# Out:
# Text(5, 10, 'last data')

# %%
plt.scatter(sample_df['avg'],sample_df['strike_rate'])

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
plt.figure(figsize=(12,6))

plt.scatter(sample_df['avg'],sample_df['strike_rate'])

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
plt.figure(figsize=(12,6))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])

for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])

# %%
plt.figure(figsize=(12,6))
plt.scatter(sample_df['avg'],sample_df['strike_rate'],s=sample_df['runs'])

plt.axhline(120,color='red')
plt.axhline(140,color='green')


for i in range(sample_df.shape[0]):
    plt.text(sample_df['avg'].values[i],sample_df['strike_rate'].values[i],sample_df['batter'].values[i])
